# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-ed2c97ec-39ee-4ecc-b1bc-41679cb55107" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed2c97ec-39ee-4ecc-b1bc-41679cb55107">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle -q

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                         title                                         size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  -------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# bhadramohit/customer-shopping-latest-trends-dataset         Customer Shopping (Latest Trends) Dataset     76KB  2024-11-23 15:26:12          11812        234  1.0
# hopesb/student-depression-dataset                           Student Depression Dataset.                  454KB  2024-11-22 17:56:03           8313        110  0.9411765
# gauthamvijayaraj/spotify-tracks-dataset-updated-every-week  Spotify Tracks Dataset (Updated every week)    5MB  2024-12-09 18:00:01           1245         26  1.0
# ...

# %%
# !wget https://www.kaggle.com/datasets/xodeum/house-pricing-with-advance-regression-techniques/download
# Out:
# --2024-12-14 19:11:20--  https://www.kaggle.com/datasets/xodeum/house-pricing-with-advance-regression-techniques/download
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fdatasets%2Fxodeum%2Fhouse-pricing-with-advance-regression-techniques%3Fresource%3Ddownload [following]
# --2024-12-14 19:11:20--  https://www.kaggle.com/account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fdatasets%2Fxodeum%2Fhouse-pricing-with-advance-regression-techniques%3Fresource%3Ddownload
# Reusing existing connection to www.kaggle.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘download’
#
# ...

# %%
# !kaggle datasets download -d xodeum/house-pricing-with-advance-regression-techniques
# Out:
# Dataset URL: https://www.kaggle.com/datasets/xodeum/house-pricing-with-advance-regression-techniques
# License(s): copyright-authors
# ...
#   0% 0.00/21.6k [00:00<?, ?B/s]
# 100% 21.6k/21.6k [00:00<00:00, 47.4MB/s]

# %%
import pandas as pd

# %%
# !unzip house-pricing-with-advance-regression-techniques.zip
# Out:
# Archive:  house-pricing-with-advance-regression-techniques.zip
#   inflating: house-pricing-with-advance-regression-methods.ipynb
#   inflating: submission1.csv

# %%
df = pd.read_csv("/content/submission1.csv")

# %%
df
# Out:
#         Id      SalePrice
# 0     1461  156633.390588
# 1     1462  195762.895873
# 2     1463  217506.844296
# 3     1464  230249.357588
# 4     1465  240294.658327
# ...    ...            ...
# 1454  2915  113062.886515
# 1455  2916  112171.293701
# 1456  2917  187684.197911
# 1457  2918  161493.266053
# 1458  2919  296906.953976
#
# [1459 rows x 2 columns]
